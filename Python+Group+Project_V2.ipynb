# %%
import requests,numpy
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
def get_text_from_elements(elements):
    """Uses list comprehension to parse out the cleaned text strings from a list of 
    elements returned from a BeautifulSoup selection.
    
    Arguments:
        elements {list} -- list of elements returned from a BeautifulSoup selection
    
    Returns:
        list -- list of cleaned text contained within the element list
    """

    return [e.text.strip() for e in elements]

# %% [markdown]
# ## Princeton Review webscraping

# %%
School_Name = []
Enrolled = []
Location = []

# %%
for i in range (20):
    url = "https://www.princetonreview.com/college-rankings?rankings=best-382-colleges&page="+str(i+1)
    page = requests.get(url)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    #get school name
    school_name = soup.select('h2 > a')
    School_Name += get_text_from_elements(school_name)
    #get enroll number
    enrolled = soup.select('li > span.black-text.bold')
    Enrolled += get_text_from_elements(enrolled)
    #get school location
    temp = soup.select('li > span.black-text')
    location = [item for item in temp if item not in enrolled]
    Location += get_text_from_elements(location)
    
#     if len(School_Name1) > len(Enrolled1):
#         print(i+1)
#         break

# %%
print(len(School_Name))
print(len(Enrolled))
print(len(Location))
# Out:
# 382
# 381
# 382

# %%
Enrolled.insert(School_Name.index("Lafayette College"),0)

# %%
Schools = pd.DataFrame({"School_Name": School_Name, "Location": Location,"Enrolled": Enrolled})
Schools.to_excel("Schools_yichuny.xlsx")

# %% [markdown]
# ## Princeton data

# %%
princeton = pd.read_excel("data/princeton_clean.xlsx")

# %%
princeton.describe()
# Out:
#                 School Enrolled Country    County State
# count              382      382     382       382   382
# unique             382      378       1       297    53
# top     Gordon College    2,428     USA  New York    NY
# freq                 1        2     382         8    46

# %% [markdown]
# In the Princeton Review dataset, we have 382 individual school from 53 states. Let's double-check what these 53 states are.

# %%
import collections
counter=collections.Counter(princeton['State'])
counter
# Out:
# Counter({' AL': 4,
#          ' AR': 1,
#          ' AZ': 3,
#          ' CA': 31,
#          ' CO': 5,
#          ' CT': 10,
#          ' DC': 5,
#          ' DE': 1,
#          ' FL': 12,
#          ' GA': 7,
#          ' HI': 1,
#          ' IA': 5,
#          ' ID': 2,
#          ' IL': 11,
#          ' IN': 8,
#          ' KS': 2,
#          ' KY': 6,
#          ' LA': 6,
#          ' Louisiana': 1,
#          ' MA': 28,
#          ' MD': 10,
#          ' ME': 6,
#          ' MI': 6,
#          ' MN': 5,
#          ' MO': 8,
#          ' MS': 2,
#          ' MT': 2,
#          ' NC': 12,
#          ' ND': 1,
#          ' NE': 2,
#          ' NH': 3,
#          ' NJ': 9,
#          ' NM': 2,
#          ' NV': 1,
#          ' NY': 46,
#          ' OH': 14,
#          ' OK': 2,
#          ' ON': 1,
#          ' OR': 5,
#          ' PA': 29,
#          ' QC': 1,
#          ' RI': 4,
#          ' SC': 5,
#          ' SD': 1,
#          ' TN': 4,
#          ' TX': 13,
#          ' UT': 3,
#          ' VA': 16,
#          ' VT': 6,
#          ' WA': 7,
#          ' WI': 5,
#          ' WV': 1,
#          ' WY': 1})

# %%
princeton[princeton['State']==' Louisiana']
# Out:
#                             School Enrolled Country      County       State
# 42  Centenary College of Louisiana      533     USA  Shreveport   Louisiana

# %%
princeton.xs(42)['State'] =  ' LA'

# %% [markdown]
# We corrected the state labeling mistake. Now we are wondering what states have the most schools that's considered as "most popular school" by princeton review.

# %%
sns.set_style("white")

ax = sns.countplot(x="State", data= princeton, order = princeton['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As we can see on the graph, the top 4 states exceeds all others states and have the most school counts. Now let's take a closer look at these four states.

# %%
counter2=collections.Counter(princeton['State'])
most_pop_states = pd.DataFrame(data=counter2.most_common()[:4])
most_pop_states.columns = ['State', 'Count']
most_pop_states
# Out:
#   State  Count
# 0    NY     46
# 1    CA     31
# 2    PA     29
# 3    MA     28

# %%
sns.set_style("white")
ax = sns.barplot(x="State", y = 'Count', data= most_pop_states)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We are also interested in learning about the enrollment of students by states.

# %%
princeton['Enrolled'] = princeton['Enrolled'].str.replace(',', '').astype(float) 
##excelent line of code from 
# https://stackoverflow.com/questions/22137723/convert-number-strings-with-commas-in-pandas-dataframe-to-float

# %%
top4_states = princeton.loc[princeton['State'].isin([' NY',' MA', ' PA', ' CA'])]

sns.set_style("white")
sns.barplot(x="Enrolled", y="State", data= top4_states,palette="Paired")
#ax.set_axis_bgcolor('white')


plt.show()

# %% [markdown]
# As the bar plot suggests, every years, top colleges in California has almost 10,000 students enrolled in the programs.

# %% [markdown]
# ## Shanghai Data

# %%
shanghai = pd.read_excel("data/Shanghai_clean.xlsx")

# %%
shanghai_us= shanghai[shanghai['Location']=='USA'].reset_index(drop=True)
len(shanghai_us)
# Out:
# 47

# %% [markdown]
# For this set of data, we have 47 school records that belong to the USA. For the purpose of this study(sample college search), we will only dive into schools in the United States

# %%
with_total_score = shanghai_us[-shanghai_us['Total Score'].isnull()]
with_total_score
# Out:
#                                          School  Total Score  \
# 0   Massachusetts Institute of Technology (MIT)        100.0
# 1                           Stanford University         92.9
# 2            University of California, Berkeley         82.8
# 3             The University of Texas at Austin         80.3
# 4               Georgia Institute of Technology         79.8
# 5    University of Illinois at Urbana-Champaign         79.4
# 6              University of Michigan-Ann Arbor         77.3
# 7                         Texas A&M; University         76.7
# 8            Purdue University - West Lafayette         75.8
# 9           University of California, San Diego         73.8
# 10                   Carnegie Mellon University         72.5
# 11        University of California, Los Angeles         71.8
# 12                         Princeton University         70.9
# 13      University of California, Santa Barbara         70.8
# 14                      Northwestern University         70.4
# 15                           Harvard University         70.2
# 16         University of Minnesota, Twin Cities         70.2
# 17           California Institute of Technology         69.5
# 18                     University of Washington         69.5
# 19         The Ohio State University - Columbus         68.2
#
#     Papers in Top 20% Journals Location
# 0                         92.5      USA
# 1                         96.7      USA
# 2                         93.4      USA
# 3                         87.4      USA
# 4                         86.6      USA
# 5                         88.3      USA
# 6                         88.1      USA
# 7                         81.2      USA
# 8                         81.9      USA
# 9                         92.1      USA
# 10                        86.2      USA
# 11                        91.6      USA
# 12                        96.6      USA
# 13                       100.0      USA
# 14                        93.3      USA
# 15                        95.6      USA
# 16                        90.9      USA
# 17                        95.3      USA
# 18                        86.0      USA
# 19                        86.2      USA

# %%
sns.regplot(y="Total Score", x="Papers in Top 20% Journals", data=with_total_score)
plt.show()

# %% [markdown]
# It seems the total score given by the website is not directly collerated with papers in top 20% journals. Regardless, all schools on the list have a pretty high rate for "papers in the top 20% journals.

# %% [markdown]
# ## Niche Data

# %%
niche = pd.read_excel("data/Niche.xlsx")

# %%
niche_update  = niche[niche["SAT_Higher"].notnull()]

# %%
niche_update = niche_update.reset_index()
niche_update[:20]
# Out:
#     index Acceptance Rate        County State  Price SAT_Lower  SAT_Higher  \
# 0       0            0.08     Cambridge    MA  21576      1460      1590.0
# 1       1            0.05      Stanford    CA  16695      1380      1580.0
# 2       2            0.07     Princeton    NJ  17732      1400      1590.0
# 3       3            0.26       Atlanta    GA  13340      1320      1500.0
# 4       4            0.08      Pasadena    CA  26839      1510      1600.0
# 5       5            0.15       Houston    TX  22061      1410      1570.0
# 6       6            0.06     New Haven    CT  18319      1420      1600.0
# 7       7            0.05     Cambridge    MA  16205      1430      1600.0
# 8       8            0.11        Durham    NC  19950      1380      1570.0
# 9       9            0.61     Melbourne    FL  31582      1060      1260.0
# 10     10            0.09  Philadelphia    PA  22944      1380      1570.0
# 11     11            0.14        Ithaca    NY  30014      1330      1530.0
# 12     12            0.29     Ann Arbor    MI  16107      1310      1500.0
# 13     13            0.19    Notre Dame    IN  26683      1350      1540.0
# 14     14             0.4        Golden    CO  25097      1250      1420.0
# 15     15            0.07      New York    NY  22973      1410      1590.0
# 16     16            0.17   Los Angeles    CA  32932      1280      1500.0
# 17     17            0.17      Berkeley    CA  17160      1270      1540.0
# 18     18            0.64       Newberg    OR  27935       960      1200.0
# 19     19            0.15      New York    NY  34754      1250      1500.0
#
#                                                School
# 0               Massachusetts Institute of Technology
# 1                                 Stanford University
# 2                                Princeton University
# 3                     Georgia Institute of Technology
# 4                  California Institute of Technology
# 5                                     Rice University
# 6                                     Yale University
# 7                                  Harvard University
# 8                                     Duke University
# 9                     Florida Institute of Technology
# 10                         University of Pennsylvania
# 11                                 Cornell University
# 12                 University of Michigan - Ann Arbor
# 13                           University of Notre Dame
# 14                           Colorado School of Mines
# 15                                Columbia University
# 16                  University of Southern California
# 17                University of California - Berkeley
# 18                              George Fox University
# 19  The Cooper Union for the Advancement of Scienc...

# %%
len(niche_update)
# Out:
# 430

# %% [markdown]
# After dropping schools that does not include SAT score, we have 430 instances to study from.

# %% [markdown]
# #### Accptance Rate

# %%
niche_update["Acceptance Rate"]= pd.to_numeric(niche_update["Acceptance Rate"],errors='coerce')
ax = sns.boxplot(x= niche_update['Acceptance Rate'])
ax.set_axis_bgcolor('white')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# #### Price

# %%
niche_update["Price"] = pd.to_numeric(niche_update["Price"],errors='coerce')
ax = sns.boxplot(x= niche_update['Price'])
ax.set_axis_bgcolor('white')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Is Price and Accptance Rate correlated?

# %%
g = sns.lmplot(y="SAT", x="Acceptance Rate",size=5, data=niche_update)
plt.show()

# %% [markdown]
# Schools with lower Acceptance Rate are more expensive. This graph indicates the more competitive institutions are also more expensive.

# %% [markdown]
# #### SAT scores

# %%
niche_update["SAT_Lower"] = pd.to_numeric(niche_update["SAT_Lower"],errors='coerce')
niche_update["SAT_Higher"] = pd.to_numeric(niche_update["SAT_Higher"],errors='coerce')

# %%
niche_update["SAT_Mean"] = niche_update[['SAT_Lower', 'SAT_Higher']].mean(axis=1)
niche_update[:20]
# Out:
#     index  Acceptance Rate        County State    Price SAT_Lower  SAT_Higher  \
# 0       0             0.08     Cambridge    MA  21576.0      1460      1590.0
# 1       1             0.05      Stanford    CA  16695.0      1380      1580.0
# 2       2             0.07     Princeton    NJ  17732.0      1400      1590.0
# 3       3             0.26       Atlanta    GA  13340.0      1320      1500.0
# 4       4             0.08      Pasadena    CA  26839.0      1510      1600.0
# 5       5             0.15       Houston    TX  22061.0      1410      1570.0
# 6       6             0.06     New Haven    CT  18319.0      1420      1600.0
# 7       7             0.05     Cambridge    MA  16205.0      1430      1600.0
# 8       8             0.11        Durham    NC  19950.0      1380      1570.0
# 9       9             0.61     Melbourne    FL  31582.0      1060      1260.0
# 10     10             0.09  Philadelphia    PA  22944.0      1380      1570.0
# 11     11             0.14        Ithaca    NY  30014.0      1330      1530.0
# 12     12             0.29     Ann Arbor    MI  16107.0      1310      1500.0
# 13     13             0.19    Notre Dame    IN  26683.0      1350      1540.0
# 14     14             0.40        Golden    CO  25097.0      1250      1420.0
# 15     15             0.07      New York    NY  22973.0      1410      1590.0
# 16     16             0.17   Los Angeles    CA  32932.0      1280      1500.0
# 17     17             0.17      Berkeley    CA  17160.0      1270      1540.0
# 18     18             0.64       Newberg    OR  27935.0       960      1200.0
# 19     19             0.15      New York    NY  34754.0      1250      1500.0
#
#                                                School  SAT_Mean
# 0               Massachusetts Institute of Technology    1525.0
# 1                                 Stanford University    1480.0
# 2                                Princeton University    1495.0
# 3                     Georgia Institute of Technology    1410.0
# 4                  California Institute of Technology    1555.0
# 5                                     Rice University    1490.0
# 6                                     Yale University    1510.0
# 7                                  Harvard University    1515.0
# 8                                     Duke University    1475.0
# 9                     Florida Institute of Technology    1160.0
# 10                         University of Pennsylvania    1475.0
# 11                                 Cornell University    1430.0
# 12                 University of Michigan - Ann Arbor    1405.0
# 13                           University of Notre Dame    1445.0
# 14                           Colorado School of Mines    1335.0
# 15                                Columbia University    1500.0
# 16                  University of Southern California    1390.0
# 17                University of California - Berkeley    1405.0
# 18                              George Fox University    1080.0
# 19  The Cooper Union for the Advancement of Scienc...    1375.0

# %% [markdown]
# #### SAT Score and Acceptance Rate

# %%
g = sns.lmplot(y="SAT_Mean", x="Acceptance Rate",size=5, data=niche_update, )
g.set(axis_bgcolor='w')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %% [markdown]
# Schools with higher SAT have lower Acceptance Rate. The more competitive schools demand higher standardized scores

# %% [markdown]
# #### SAT Score & Price

# %%
g = sns.lmplot(y="SAT_Mean", x="Price",size=4, data=niche_update)
g.set(axis_bgcolor='w')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %% [markdown]
# Schools requiring higher SAT scores are more expensive

# %% [markdown]
# ## Top 50 schools in top 4 states, how pricey?

# %%
top4_states_ni= niche_update[niche_update['State'].isin(['NY','MA', 'PA', 'CA'])]
top50_top4 = top4_states_ni[:50]
top50_top4[:20]
# Out:
#     index  Acceptance Rate        County State    Price SAT_Lower  SAT_Higher  \
# 0       0             0.08     Cambridge    MA  21576.0      1460      1590.0
# 1       1             0.05      Stanford    CA  16695.0      1380      1580.0
# 4       4             0.08      Pasadena    CA  26839.0      1510      1600.0
# 7       7             0.05     Cambridge    MA  16205.0      1430      1600.0
# 10     10             0.09  Philadelphia    PA  22944.0      1380      1570.0
# 11     11             0.14        Ithaca    NY  30014.0      1330      1530.0
# 15     15             0.07      New York    NY  22973.0      1410      1590.0
# 16     16             0.17   Los Angeles    CA  32932.0      1280      1500.0
# 17     17             0.17      Berkeley    CA  17160.0      1270      1540.0
# 19     19             0.15      New York    NY  34754.0      1250      1500.0
# 23     23             0.22    Pittsburgh    PA  35250.0      1380      1550.0
# 29     29             0.29        Boston    MA  29998.0      1330      1510.0
# 30     30             0.18   Los Angeles    CA  14236.0      1160      1470.0
# 34     34             0.44          Troy    NY  37434.0      1280      1480.0
# 35     35             0.13     Claremont    CA  35460.0      1420      1580.0
# 36     36             0.48     Worcester    MA  40666.0      1310      1480.0
# 37     37             0.14       Medford    MA  28076.0      1370      1520.0
# 43     43             0.48     Worcester    MA  40666.0      1310      1480.0
# 49     49             0.26     Bethlehem    PA  27478.0      1230      1420.0
# 51     51             0.13    Swarthmore    PA  19641.0      1305      1530.0
#
#                                                School  SAT_Mean
# 0               Massachusetts Institute of Technology    1525.0
# 1                                 Stanford University    1480.0
# 4                  California Institute of Technology    1555.0
# 7                                  Harvard University    1515.0
# 10                         University of Pennsylvania    1475.0
# 11                                 Cornell University    1430.0
# 15                                Columbia University    1500.0
# 16                  University of Southern California    1390.0
# 17                University of California - Berkeley    1405.0
# 19  The Cooper Union for the Advancement of Scienc...    1375.0
# 23                         Carnegie Mellon University    1465.0
# 29                            Northeastern University    1420.0
# 30             University of California - Los Angeles    1315.0
# 34                   Rensselaer Polytechnic Institute    1380.0
# 35                                Harvey Mudd College    1500.0
# 36                    Worcester Polytechnic Institute    1395.0
# 37                                   Tufts University    1445.0
# 43                    Worcester Polytechnic Institute    1395.0
# 49                                  Lehigh University    1325.0
# 51                                 Swarthmore College    1417.5

# %%
len(top50_top4)
# Out:
# 50

# %%
g = sns.lmplot(y="SAT_Mean", x="Price",size=4, data=top50_top4)
g.set(axis_bgcolor='w')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %% [markdown]
# Schools located in top 4 states are equally demanding in standardized scores. However, their price range is quite wide

# %%
g = sns.lmplot(y="SAT_Mean", x="Acceptance Rate",size=4, data=top50_top4)
g.set(axis_bgcolor='w')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %% [markdown]
# However, better ranked schools keep their prestige by accepting candidates with highest standardized scores. This graph shows how an SAT score determines the rate of acceptance at highly prestigious schools in the top 4 states

# %% [markdown]
# ## Merge files - 3 Data Sources

# %%
niche_update.head()
# Out:
#    index Acceptance Rate     County State  Price  SAT_Lower  SAT_Higher  \
# 0      0            0.08  Cambridge    MA  21576       1460      1590.0
# 1      1            0.05   Stanford    CA  16695       1380      1580.0
# 2      2            0.07  Princeton    NJ  17732       1400      1590.0
# 3      3            0.26    Atlanta    GA  13340       1320      1500.0
# 4      4            0.08   Pasadena    CA  26839       1510      1600.0
#
#                                   School
# 0  Massachusetts Institute of Technology
# 1                    Stanford University
# 2                   Princeton University
# 3        Georgia Institute of Technology
# 4     California Institute of Technology

# %%
princeton.head()
# Out:
#                 School  Enrolled Country      County State
# 0  Agnes Scott College     921.0     USA     Decatur    GA
# 1       Albion College    1568.0     USA      Albion    MI
# 2    Alfred University    1960.0     USA      Alfred    NY
# 3    Allegheny College    1802.0     USA   Meadville    PA
# 4  American University    8123.0     USA  Washington    DC

# %%
shanghai_us.head()
# Out:
#                                         School  Total Score  \
# 0  Massachusetts Institute of Technology (MIT)        100.0
# 1                          Stanford University         92.9
# 2           University of California, Berkeley         82.8
# 3            The University of Texas at Austin         80.3
# 4              Georgia Institute of Technology         79.8
#
#    Papers in Top 20% Journals Location
# 0                        92.5      USA
# 1                        96.7      USA
# 2                        93.4      USA
# 3                        87.4      USA
# 4                        86.6      USA

# %%
# merged = princeton.merge(shanghai,on = "School", how = 'outer')
# merged.to_excel("Merged.xlsx",index = False)


merged_temp = niche_update.merge(princeton, on = "School", how = 'outer')

# %%
merged_temp.head()
# Out:
#    index Acceptance Rate   County_x State_x  Price  SAT_Lower  SAT_Higher  \
# 0    0.0            0.08  Cambridge      MA  21576     1460.0      1590.0
# 1    1.0            0.05   Stanford      CA  16695     1380.0      1580.0
# 2    2.0            0.07  Princeton      NJ  17732     1400.0      1590.0
# 3    3.0            0.26    Atlanta      GA  13340     1320.0      1500.0
# 4    4.0            0.08   Pasadena      CA  26839     1510.0      1600.0
#
#                                   School  Enrolled Country   County_y State_y
# 0  Massachusetts Institute of Technology    4547.0     USA  Cambridge      MA
# 1                    Stanford University    7062.0     USA   Stanford      CA
# 2                   Princeton University    5394.0     USA  Princeton      NJ
# 3        Georgia Institute of Technology   15572.0     USA    Atlanta      GA
# 4     California Institute of Technology     961.0     USA   Pasadena      CA

# %%
merged = merged_temp.merge(shanghai_us,on = "School", how = 'outer')
merged.head()
# Out:
#    index Acceptance Rate   County_x State_x  Price  SAT_Lower  SAT_Higher  \
# 0    0.0            0.08  Cambridge      MA  21576     1460.0      1590.0
# 1    1.0            0.05   Stanford      CA  16695     1380.0      1580.0
# 2    2.0            0.07  Princeton      NJ  17732     1400.0      1590.0
# 3    3.0            0.26    Atlanta      GA  13340     1320.0      1500.0
# 4    4.0            0.08   Pasadena      CA  26839     1510.0      1600.0
#
#                                   School  Enrolled Country   County_y State_y  \
# 0  Massachusetts Institute of Technology    4547.0     USA  Cambridge      MA
# 1                    Stanford University    7062.0     USA   Stanford      CA
# 2                   Princeton University    5394.0     USA  Princeton      NJ
# 3        Georgia Institute of Technology   15572.0     USA    Atlanta      GA
# 4     California Institute of Technology     961.0     USA   Pasadena      CA
#
#    Total Score  Papers in Top 20% Journals Location
# 0          NaN                         NaN      NaN
# 1         92.9                        96.7      USA
# 2         70.9                        96.6      USA
# 3         79.8                        86.6      USA
# 4         69.5                        95.3      USA

# %%
merged.drop(columns=['Location', 'Country'])
# Out:
#      index Acceptance Rate      County_x State_x  Price  SAT_Lower  \
# 0      0.0            0.08     Cambridge      MA  21576     1460.0
# 1      1.0            0.05      Stanford      CA  16695     1380.0
# 2      2.0            0.07     Princeton      NJ  17732     1400.0
# 3      3.0            0.26       Atlanta      GA  13340     1320.0
# 4      4.0            0.08      Pasadena      CA  26839     1510.0
# 5      5.0            0.15       Houston      TX  22061     1410.0
# 6      6.0            0.06     New Haven      CT  18319     1420.0
# 7      7.0            0.05     Cambridge      MA  16205     1430.0
# 8      8.0            0.11        Durham      NC  19950     1380.0
# 9      9.0            0.61     Melbourne      FL  31582     1060.0
# 10   113.0            0.61     Melbourne      FL  31582     1060.0
# 11   198.0            0.61     Melbourne      FL  31582     1060.0
# 12   279.0            0.61     Melbourne      FL  31582     1060.0
# 13    10.0            0.09  Philadelphia      PA  22944     1380.0
# 14    11.0            0.14        Ithaca      NY  30014     1330.0
# 15    12.0            0.29     Ann Arbor      MI  16107     1310.0
# 16    13.0            0.19    Notre Dame      IN  26683     1350.0
# 17    14.0             0.4        Golden      CO  25097     1250.0
# 18    15.0            0.07      New York      NY  22973     1410.0
# 19    16.0            0.17   Los Angeles      CA  32932     1280.0
# 20    17.0            0.17      Berkeley      CA  17160     1270.0
# 21    18.0            0.64       Newberg      OR  27935      960.0
# 22   195.0            0.64       Newberg      OR  27935      960.0
# 23   441.0            0.64       Newberg      OR  27935      960.0
# 24    19.0            0.15      New York      NY  34754     1250.0
# 25    20.0             0.6     Champaign      IL  16683     1285.0
# 26    21.0            0.11     Nashville      TN  23150     1420.0
# 27   369.0            0.11     Nashville      TN  23150     1420.0
# 28    22.0             0.4        Austin      TX  16010     1140.0
# 29    23.0            0.22    Pittsburgh      PA  35250     1380.0
# ..     ...             ...           ...     ...    ...        ...
# 667    NaN             NaN           NaN     NaN    NaN        NaN
# 668    NaN             NaN           NaN     NaN    NaN        NaN
# 669    NaN             NaN           NaN     NaN    NaN        NaN
# 670    NaN             NaN           NaN     NaN    NaN        NaN
# 671    NaN             NaN           NaN     NaN    NaN        NaN
# 672    NaN             NaN           NaN     NaN    NaN        NaN
# 673    NaN             NaN           NaN     NaN    NaN        NaN
# 674    NaN             NaN           NaN     NaN    NaN        NaN
# 675    NaN             NaN           NaN     NaN    NaN        NaN
# 676    NaN             NaN           NaN     NaN    NaN        NaN
# 677    NaN             NaN           NaN     NaN    NaN        NaN
# 678    NaN             NaN           NaN     NaN    NaN        NaN
# 679    NaN             NaN           NaN     NaN    NaN        NaN
# 680    NaN             NaN           NaN     NaN    NaN        NaN
# 681    NaN             NaN           NaN     NaN    NaN        NaN
# 682    NaN             NaN           NaN     NaN    NaN        NaN
# 683    NaN             NaN           NaN     NaN    NaN        NaN
# 684    NaN             NaN           NaN     NaN    NaN        NaN
# 685    NaN             NaN           NaN     NaN    NaN        NaN
# 686    NaN             NaN           NaN     NaN    NaN        NaN
# 687    NaN             NaN           NaN     NaN    NaN        NaN
# 688    NaN             NaN           NaN     NaN    NaN        NaN
# 689    NaN             NaN           NaN     NaN    NaN        NaN
# 690    NaN             NaN           NaN     NaN    NaN        NaN
# 691    NaN             NaN           NaN     NaN    NaN        NaN
# 692    NaN             NaN           NaN     NaN    NaN        NaN
# 693    NaN             NaN           NaN     NaN    NaN        NaN
# 694    NaN             NaN           NaN     NaN    NaN        NaN
# 695    NaN             NaN           NaN     NaN    NaN        NaN
# 696    NaN             NaN           NaN     NaN    NaN        NaN
#
#      SAT_Higher                                             School  Enrolled  \
# 0        1590.0              Massachusetts Institute of Technology    4547.0
# 1        1580.0                                Stanford University    7062.0
# 2        1590.0                               Princeton University    5394.0
# 3        1500.0                    Georgia Institute of Technology   15572.0
# 4        1600.0                 California Institute of Technology     961.0
# 5        1570.0                                    Rice University     102.0
# 6        1600.0                                    Yale University    5532.0
# 7        1600.0                                 Harvard University       NaN
# 8        1570.0                                    Duke University    6609.0
# 9        1260.0                    Florida Institute of Technology       NaN
# 10       1260.0                    Florida Institute of Technology       NaN
# 11       1260.0                    Florida Institute of Technology       NaN
# 12       1260.0                    Florida Institute of Technology       NaN
# 13       1570.0                         University of Pennsylvania   10033.0
# 14       1530.0                                 Cornell University   14907.0
# 15       1500.0                 University of Michigan - Ann Arbor       NaN
# 16       1540.0                           University of Notre Dame    8576.0
# 17       1420.0                           Colorado School of Mines       NaN
# 18       1590.0                                Columbia University    6231.0
# 19       1500.0                  University of Southern California   19287.0
# 20       1540.0                University of California - Berkeley       NaN
# 21       1200.0                              George Fox University       NaN
# 22       1200.0                              George Fox University       NaN
# 23       1200.0                              George Fox University       NaN
# 24       1500.0  The Cooper Union for the Advancement of Scienc...     867.0
# 25       1480.0         University of Illinois at Urbana-Champaign   33932.0
# 26       1590.0                              Vanderbilt University    6885.0
# 27       1590.0                              Vanderbilt University    6885.0
# 28       1410.0                       University of Texas - Austin       NaN
# 29       1550.0                         Carnegie Mellon University    6896.0
# ..          ...                                                ...       ...
# 667         NaN                                    Whitman College    1510.0
# 668         NaN                                   Whittier College    1681.0
# 669         NaN                              Willamette University    2112.0
# 670         NaN                             William Jewell College     928.0
# 671         NaN                                   Williams College    2061.0
# 672         NaN                              Wittenberg University    1857.0
# 673         NaN                                    Wofford College    1592.0
# 674         NaN                             Xavier University (OH)    4645.0
# 675         NaN                     Xavier University of Louisiana    2293.0
# 676         NaN        Massachusetts Institute of Technology (MIT)       NaN
# 677         NaN                 University of California, Berkeley       NaN
# 678         NaN                  The University of Texas at Austin       NaN
# 679         NaN                   University of Michigan-Ann Arbor       NaN
# 680         NaN                              Texas A&M; University       NaN
# 681         NaN                 Purdue University - West Lafayette       NaN
# 682         NaN                University of California, San Diego       NaN
# 683         NaN              University of California, Los Angeles       NaN
# 684         NaN            University of California, Santa Barbara       NaN
# 685         NaN               University of Minnesota, Twin Cities       NaN
# 686         NaN               The Ohio State University - Columbus       NaN
# 687         NaN          North Carolina State University - Raleigh       NaN
# 688         NaN    Pennsylvania State University - University Park       NaN
# 689         NaN                            The University of Akron       NaN
# 690         NaN                  University of Colorado at Boulder       NaN
# 691         NaN                    University of California, Davis       NaN
# 692         NaN                   University of California, Irvine       NaN
# 693         NaN                University of Massachusetts Amherst       NaN
# 694         NaN                University of Tennessee - Knoxville       NaN
# 695         NaN                  University of Wisconsin - Madison       NaN
# 696         NaN  Virginia Polytechnic Institute and State Unive...       NaN
#
#          County_y State_y  Total Score  Papers in Top 20% Journals
# 0       Cambridge      MA          NaN                         NaN
# 1        Stanford      CA         92.9                        96.7
# 2       Princeton      NJ         70.9                        96.6
# 3         Atlanta      GA         79.8                        86.6
# 4        Pasadena      CA         69.5                        95.3
# 5         Houston      TX          NaN                        94.8
# 6       New Haven      CT          NaN                         NaN
# 7             NaN     NaN         70.2                        95.6
# 8          Durham      NC          NaN                        92.5
# 9             NaN     NaN          NaN                         NaN
# 10            NaN     NaN          NaN                         NaN
# 11            NaN     NaN          NaN                         NaN
# 12            NaN     NaN          NaN                         NaN
# 13   Philadelphia      PA          NaN                        93.0
# 14         Ithaca      NY          NaN                        90.6
# 15            NaN     NaN          NaN                         NaN
# 16     Notre Dame      IN          NaN                         NaN
# 17            NaN     NaN          NaN                         NaN
# 18       New York      NY          NaN                        92.4
# 19    Los Angeles      CA          NaN                        86.6
# 20            NaN     NaN          NaN                         NaN
# 21            NaN     NaN          NaN                         NaN
# 22            NaN     NaN          NaN                         NaN
# 23            NaN     NaN          NaN                         NaN
# 24       New York      NY          NaN                         NaN
# 25      Champaign      IL         79.4                        88.3
# 26      Nashville      TN          NaN                         NaN
# 27      Nashville      TN          NaN                         NaN
# 28            NaN     NaN          NaN                         NaN
# 29     Pittsburgh      PA         72.5                        86.2
# ..            ...     ...          ...                         ...
# 667   Walla Walla      WA          NaN                         NaN
# 668      Whittier      CA          NaN                         NaN
# 669         Salem      OR          NaN                         NaN
# 670       Liberty      MO          NaN                         NaN
# 671  Williamstown      MA          NaN                         NaN
# 672   Springfield      OH          NaN                         NaN
# 673   Spartanburg      SC          NaN                         NaN
# 674    Cincinnati      OH          NaN                         NaN
# 675   New Orleans      LA          NaN                         NaN
# 676           NaN     NaN        100.0                        92.5
# 677           NaN     NaN         82.8                        93.4
# 678           NaN     NaN         80.3                        87.4
# 679           NaN     NaN         77.3                        88.1
# 680           NaN     NaN         76.7                        81.2
# 681           NaN     NaN         75.8                        81.9
# 682           NaN     NaN         73.8                        92.1
# 683           NaN     NaN         71.8                        91.6
# 684           NaN     NaN         70.8                       100.0
# 685           NaN     NaN         70.2                        90.9
# 686           NaN     NaN         68.2                        86.2
# 687           NaN     NaN          NaN                        82.7
# 688           NaN     NaN          NaN                        87.6
# 689           NaN     NaN          NaN                        92.1
# 690           NaN     NaN          NaN                        94.4
# 691           NaN     NaN          NaN                        85.8
# 692           NaN     NaN          NaN                        84.9
# 693           NaN     NaN          NaN                        91.8
# 694           NaN     NaN          NaN                        85.6
# 695           NaN     NaN          NaN                        82.4
# 696           NaN     NaN          NaN                        79.4
#
# [697 rows x 13 columns]
